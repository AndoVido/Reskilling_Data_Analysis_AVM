# %%
import pandas as pd

# %%
partidos = pd.read_csv('partidos_atp_2000_2024.csv')
partidos
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              2000-301                      Auckland    Hard
# 1                              2000-301                      Auckland    Hard
# 2                              2000-301                      Auckland    Hard
# 3                              2000-301                      Auckland    Hard
# 4                              2000-301                      Auckland    Hard
# ...                                 ...                           ...     ...
# 74901  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 74902  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 74903  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 74904  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 74905  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
# ...

# %%
us_open = partidos[partidos['tourney_name'] == 'us open']

# %%
us_open2 = partidos[partidos['tourney_name'] == 'Us open']
us_open2
# Out:
# Empty DataFrame
# Columns: [tourney_id, tourney_name, surface, draw_size, tourney_level, tourney_date, match_num, winner_id, winner_seed, winner_entry, winner_name, winner_hand, winner_ht, winner_ioc, winner_age, loser_id, loser_seed, loser_entry, loser_name, loser_hand, loser_ht, loser_ioc, loser_age, score, best_of, round, minutes, w_ace, w_df, w_svpt, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_bpSaved, w_bpFaced, l_ace, l_df, l_svpt, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_bpSaved, l_bpFaced, winner_rank, winner_rank_points, loser_rank, loser_rank_points, year]
# Index: []
#
# [0 rows x 50 columns]

# %%
us_open.tail(20)
# Out:
# Empty DataFrame
# Columns: [tourney_id, tourney_name, surface, draw_size, tourney_level, tourney_date, match_num, winner_id, winner_seed, winner_entry, winner_name, winner_hand, winner_ht, winner_ioc, winner_age, loser_id, loser_seed, loser_entry, loser_name, loser_hand, loser_ht, loser_ioc, loser_age, score, best_of, round, minutes, w_ace, w_df, w_svpt, w_1stIn, w_1stWon, w_2ndWon, w_SvGms, w_bpSaved, w_bpFaced, l_ace, l_df, l_svpt, l_1stIn, l_1stWon, l_2ndWon, l_SvGms, l_bpSaved, l_bpFaced, winner_rank, winner_rank_points, loser_rank, loser_rank_points, year]
# Index: []
#
# [0 rows x 50 columns]

# %%
partidos.isnull().sum()
# Out:
# tourney_id                0
# tourney_name              0
# surface                  53
# draw_size                 0
# tourney_level             0
# tourney_date              0
# match_num                 0
# winner_id                 0
# winner_seed           43786
# winner_entry          65400
# winner_name               0
# winner_hand               0
# winner_ht              1425
# winner_ioc                0
# winner_age                5
# loser_id                  0
# loser_seed            57668
# loser_entry           59484
# loser_name                0
# loser_hand                4
# loser_ht               2909
# loser_ioc                 0
# loser_age                 3
# score                     0
# best_of                   0
# round                     0
# minutes                8174
# w_ace                  6520
# w_df                   6520
# w_svpt                 6520
# w_1stIn                6520
# w_1stWon               6520
# w_2ndWon               6520
# ...

# %%
partidos['tourney_name'] = partidos['tourney_name'].str.strip().str.lower()

# %%
grand_slams_2000_2024 = partidos[(partidos['tourney_name'] == 'us open') | (partidos['tourney_name'] == 'australian open') | (partidos['tourney_name'] == 'roland garros') | (partidos['tourney_name'] == 'wimbledon')]
grand_slams_2000_2024
# Out:
#       tourney_id   tourney_name surface  draw_size tourney_level  \
# 2130    2000-520  roland garros    Clay        128             G
# 2131    2000-520  roland garros    Clay        128             G
# 2132    2000-520  roland garros    Clay        128             G
# 2133    2000-520  roland garros    Clay        128             G
# 2134    2000-520  roland garros    Clay        128             G
# ...          ...            ...     ...        ...           ...
# 74139   2024-560        us open    Hard        128             G
# 74140   2024-560        us open    Hard        128             G
# 74141   2024-560        us open    Hard        128             G
# 74142   2024-560        us open    Hard        128             G
# 74143   2024-560        us open    Hard        128             G
#
#        tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 2130       20000529          1     101736          1.0          NaN  ...
# ...

# %%
grand_slams_2000_2024
# Out:
#       tourney_id   tourney_name surface  draw_size tourney_level  \
# 2130    2000-520  roland garros    Clay        128             G
# 2131    2000-520  roland garros    Clay        128             G
# 2132    2000-520  roland garros    Clay        128             G
# 2133    2000-520  roland garros    Clay        128             G
# 2134    2000-520  roland garros    Clay        128             G
# ...          ...            ...     ...        ...           ...
# 74139   2024-560        us open    Hard        128             G
# 74140   2024-560        us open    Hard        128             G
# 74141   2024-560        us open    Hard        128             G
# 74142   2024-560        us open    Hard        128             G
# 74143   2024-560        us open    Hard        128             G
#
#        tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 2130       20000529          1     101736          1.0          NaN  ...
# ...

# %%
grand_slams_2000_2024.to_csv('grand_slams_2000_2024.csv', index=False)
