# %%
import pandas as pd

# %%
torneos_unidos = pd.read_csv('partidos_atp_2000_2024.csv')
torneos_unidos
# Out:
#                              tourney_id                  tourney_name surface  \
# 0                              2000-301                      Auckland    Hard
# 1                              2000-301                      Auckland    Hard
# 2                              2000-301                      Auckland    Hard
# 3                              2000-301                      Auckland    Hard
# 4                              2000-301                      Auckland    Hard
# ...                                 ...                           ...     ...
# 74901  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 74902  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 74903  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 74904  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 74905  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
# ...

# %%
torneos_unidos['tourney_name'] = torneos_unidos['tourney_name'].str.strip().str.lower()

# %%
grand_slams = torneos_unidos[torneos_unidos['tourney_name'].isin(['us open','wimbledon','roland garros','australian open'])]
grand_slams
# Out:
#       tourney_id   tourney_name surface  draw_size tourney_level  \
# 2130    2000-520  roland garros    Clay        128             G
# 2131    2000-520  roland garros    Clay        128             G
# 2132    2000-520  roland garros    Clay        128             G
# 2133    2000-520  roland garros    Clay        128             G
# 2134    2000-520  roland garros    Clay        128             G
# ...          ...            ...     ...        ...           ...
# 74139   2024-560        us open    Hard        128             G
# 74140   2024-560        us open    Hard        128             G
# 74141   2024-560        us open    Hard        128             G
# 74142   2024-560        us open    Hard        128             G
# 74143   2024-560        us open    Hard        128             G
#
#        tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 2130       20000529          1     101736          1.0          NaN  ...
# ...

# %%
players = pd.read_csv('atp_players.csv')
players
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14880\4038618507.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv('atp_players.csv')
#        player_id      name_first          name_last hand         dob  ioc  \
# 0         100001         Gardnar             Mulloy    R  19131122.0  USA
# 1         100002          Pancho             Segura    R  19210620.0  ECU
# 2         100003           Frank            Sedgman    R  19271002.0  AUS
# 3         100004        Giuseppe              Merlo    R  19271011.0  ITA
# 4         100005         Richard           Gonzalez    R  19280509.0  USA
# ...          ...             ...                ...  ...         ...  ...
# 65984     213700          Matvei           Kobiakov    U         NaN  RUS
# 65985     213701  Tobia Costanzo  Baragiola Mordini    U         NaN  ITA
# 65986     213702         Dominik           Wijntjes    U         NaN  NZL
# ...

# %%
players['full_name'] = players['name_first'] + " " + players['name_last']
players
# Out:
#        player_id      name_first          name_last hand         dob  ioc  \
# 0         100001         Gardnar             Mulloy    R  19131122.0  USA
# 1         100002          Pancho             Segura    R  19210620.0  ECU
# 2         100003           Frank            Sedgman    R  19271002.0  AUS
# 3         100004        Giuseppe              Merlo    R  19271011.0  ITA
# 4         100005         Richard           Gonzalez    R  19280509.0  USA
# ...          ...             ...                ...  ...         ...  ...
# 65984     213700          Matvei           Kobiakov    U         NaN  RUS
# 65985     213701  Tobia Costanzo  Baragiola Mordini    U         NaN  ITA
# 65986     213702         Dominik           Wijntjes    U         NaN  NZL
# 65987     213703             Sam            Wensley    U         NaN  AUS
# 65988     213704           Harry            Roberts    U         NaN  AUS
#
#        height wikidata_id                         full_name
# ...

# %%
players_top10 = players[players['full_name'].isin(['Carlos Alcaraz','Jannik Sinner','Alexander Zverev','Taylor Fritz','Jack Draper','Ben Shelton','Novak Djokovic','Alex de Minaur','Holger Rune','Lorenzo Musetti'])]
players_top10
# Out:
#        player_id name_first name_last hand         dob  ioc  height  \
# 643       100644  Alexander    Zverev    R  19970420.0  GER   198.0
# 4919      104925      Novak  Djokovic    R  19870522.0  SRB   188.0
# 26187     126203     Taylor     Fritz    R  19971028.0  USA   196.0
# 58459     206173     Jannik    Sinner    R  20010816.0  ITA   191.0
# 59804     207518    Lorenzo   Musetti    R  20020303.0  ITA   185.0
# 60019     207733       Jack    Draper    L  20011222.0  GBR   193.0
# 60275     207989     Carlos   Alcaraz    R  20030505.0  ESP   183.0
# 60315     208029     Holger      Rune    R  20030429.0  DEN   188.0
# 62383     210097        Ben   Shelton    L  20021009.0  USA   193.0
#
#       wikidata_id         full_name
# 643     Q13990552  Alexander Zverev
# 4919        Q5812    Novak Djokovic
# 26187   Q17660516      Taylor Fritz
# 58459   Q54812588     Jannik Sinner
# 59804   Q54813043   Lorenzo Musetti
# 60019   Q65030599       Jack Draper
# ...

# %%
premios = pd.read_csv('melt premios tennis.csv')
premios
# Out:
#       Unnamed: 0  year             tourney key round      premio €
# 0              0  2000          us open - 2000     W  1.643167e+06
# 1              1  2001          us open - 2001     W  1.684904e+06
# 2              2  2002          us open - 2002     W  1.727700e+06
# 3              3  2003          us open - 2003     W  1.771584e+06
# 4              4  2004          us open - 2004     W  1.816582e+06
# ...          ...   ...                     ...   ...           ...
# 1095        1095  2020  australian open - 2020    Q1  3.165882e+04
# 1096        1096  2021  australian open - 2021    Q1  3.246296e+04
# 1097        1097  2022  australian open - 2022    Q1  3.328752e+04
# 1098        1098  2023  australian open - 2023    Q1  3.413302e+04
# 1099        1099  2024  australian open - 2024    Q1  3.500000e+04
#
# [1100 rows x 5 columns]
